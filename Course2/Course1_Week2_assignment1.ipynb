# %%
import graphlab

# %%
sales = graphlab.SFrame('home_data.gl/')
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to vthukral@gmail.comand will expire on September 26, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-4948 - Server binary: C:\Python27\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\vaibhavt\AppData\Local\Temp\graphlab_server_1443970151.log.0
# [INFO] GraphLab Server Version: 1.6.1

# %%
graphlab.canvas.set_target('ipynb')

# %%
sales.show(view='BoxWhisker Plot', x='zipcode', y='price')

# %%
sales['zipcode']
# Out:
# dtype: str
# Rows: 21613
# ['98178', '98125', '98028', '98136', '98074', '98053', '98003', '98198', '98146', '98038', '98007', '98115', '98028', '98074', '98107', '98126', '98019', '98103', '98002', '98003', '98133', '98040', '98092', '98030', '98030', '98002', '98119', '98112', '98115', '98052', '98027', '98133', '98117', '98117', '98058', '98115', '98052', '98107', '98001', '98056', '98074', '98166', '98053', '98119', '98058', '98019', '98023', '98007', '98115', '98070', '98148', '98056', '98117', '98117', '98105', '98105', '98042', '98042', '98008', '98059', '98166', '98148', '98166', '98115', '98122', '98144', '98004', '98001', '98042', '98004', '98005', '98034', '98125', '98038', '98042', '98075', '98008', '98116', '98133', '98010', '98038', '98038', '98118', '98059', '98125', '98119', '98092', '98056', '98056', '98136', '98023', '98199', '98023', '98117', '98117', '98040', '98032', '98023', '98038', '98045', ... ]

# %%
sales['zip']
# Out:
# 68

# %%
len(sales[sales['zipcode'] == '98039'])
# Out:
# 50

# %%
costlyhouses = sales[sales['zipcode'] == '98039']

# %%
mean(costlyhouses['price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4392b700b36c> in <module>()
# ----> 1 mean(costlyhouses['price'])
#
# NameError: name 'mean' is not defined

# %%
costlyhouses.show()

# %%
len(sales[sales['sqft_living'] > 2000 and sales['sqft_living'] <= 4000])
# Out:
# 20830

# %%
len(sales)
# Out:
# 21613

# %%
float(len(sales[sales['sqft_living'] > 2000 and sales['sqft_living'] <= 4000])) / len(sales)
# Out:
# 0.9637718040068477

# %%
len(sales[(sales['sqft_living'] > 2000) & (sales['sqft_living'] <= 4000)])
# Out:
# 9118

# %%
9118./21613
# Out:
# 0.42187572294452413

# %%
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house				
'grade', # measure of quality of construction				
'waterfront', # waterfront property				
'view', # type of view				
'sqft_above', # square feet above ground				
'sqft_basement', # square feet in basement				
'yr_built', # the year built				
'yr_renovated', # the year renovated				
'lat', 'long', # the lat-long of the parcel				
'sqft_living15', # average sq.ft. of 15 nearest neighbors 				
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
advanced_features
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'zipcode',
#  'condition',
#  'grade',
#  'waterfront',
#  'view',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
costlyhouses['price'].mean()
# Out:
# 2160606.5999999996

# %%
train_data, test_data = sales.random_split(.8, seed=0)

# %%
len(train_data), len(test_data)
# Out:
# (17384, 4229)

# %%
advanced_model = graphlab.linear_regression.create(train_data, target='price', features=advanced_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
#
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 16477
# PROGRESS: Number of features          : 18
# PROGRESS: Number of unpacked features : 18
# PROGRESS: Number of coefficients    : 127
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# ...

# %%
advancedmodel_prices = advanced_model.evaluate(test_data)

# %%
advancedmodel_prices
# Out:
# {'max_error': 3519025.5477122515, 'rmse': 156731.7108722029}

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
my_model = graphlab.linear_regression.create(train_data, target='price', features=my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
#
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 16443
# PROGRESS: Number of features          : 6
# PROGRESS: Number of unpacked features : 6
# PROGRESS: Number of coefficients    : 115
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# ...

# %%
mymodel_prices = my_model.evaluate(test_data)

# %%
mymodel_prices
# Out:
# {'max_error': 3536082.1757960743, 'rmse': 180742.86905024791}

# %%
mymodel_prices['rmse'] - advancedmodel_prices['rmse']
# Out:
# 24011.158178045007
